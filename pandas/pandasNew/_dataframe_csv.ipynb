# %%
import pandas as pd
import numpy as np

# %%
## read csv file
read_csv_file = pd.read_csv("dataset\\titanic.csv")

# %%
## read csv file
read_csv_file1 = pd.read_csv("dataset\\titanic.csv",sep=',')

# %%
read_csv_file1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# read table through the csv file
read_table_file = pd.read_table("dataset\\titanic.csv",sep=',')

# %%
read_table_file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
read_csv_file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## set header "None"
read_csv_file1 = pd.read_csv("dataset\\titanic.csv", header=None)

# %%
read_csv_file1
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
## set names in csv file
read_csv_file1 = pd.read_csv("dataset\\titanic.csv",  names = ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'])
read_csv_file1
# Out:
#                                                                                                 PassengerId  \
# PassengerId Survived Pclass Name                                               Sex    Age SibSp       Parch
# 1           0        3      Braund, Mr. Owen Harris                            male   22  1               0
# 2           1        1      Cumings, Mrs. John Bradley (Florence Briggs Tha... female 38  1               0
# 3           1        3      Heikkinen, Miss. Laina                             female 26  0               0
# 4           1        1      Futrelle, Mrs. Jacques Heath (Lily May Peel)       female 35  1               0
# ...                                                                                                     ...
# 887         0        2      Montvila, Rev. Juozas                              male   27  0               0
# 888         1        1      Graham, Miss. Margaret Edith                       female 19  0               0
# ...

# %%
## set names in csv file
read_csv_file1 = pd.read_csv("dataset\\titanic.csv",  index_col = ['PassengerId', 'Survived'])
read_csv_file1
# Out:
#                       Pclass  \
# PassengerId Survived
# 1           0              3
# 2           1              1
# 3           1              3
# 4           1              1
# 5           0              3
# ...                      ...
# 887         0              2
# 888         1              1
# 889         0              3
# 890         1              1
# 891         0              3
#
#                                                                    Name  \
# PassengerId Survived
# 1           0                                   Braund, Mr. Owen Harris
# 2           1         Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1                                    Heikkinen, Miss. Laina
# 4           1              Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5           0                                  Allen, Mr. William Henry
# ...                                                                 ...
# ...
